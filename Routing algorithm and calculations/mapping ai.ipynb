# %%
pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=c5a689595671927a3b66109d074d976606b2f531a610a957bc01f62490a7d69f
#   Stored in directory: c:\users\kosman\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from openai import AzureOpenAI

# Initialize the Azure OpenAI client
client = AzureOpenAI(
    api_key="e0ff7b49590143a4a6fa62789c9fce15",
    api_version="2023-05-15",
    azure_endpoint="https://moopenai.openai.azure.com/"
)

# %%
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route(conversation):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        return response.choices[0].message.content.strip()
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Prompt the user to input the system message and the user message
system_message = input("Please enter the system message: ")
user_message = input("Please enter your message: ")

# Construct the conversation with the provided system message and user message
conversation = [
    {"role": "system", "content": f"{system_message}"},
    {"role": "user", "content": user_message}
]

# Call the get_route function with the conversation
route = get_route(conversation)

print("Route Directions:")
print(route)
# Out:
# Please enter the system message: hello i want to go from mall of qatar to airport
# Please enter your message: hello i want to go from Mall of qatar to airport
# Route Directions:
# There are different modes of transportation to go from Mall of Qatar to the airport in Doha:
#
# 1. Taxi: You can hire a taxi from the taxi stand outside Mall of Qatar. The journey takes around 20-30 minutes depending on traffic. The estimated fare will be around QAR 50-60.
#
# 2. Private Car: You can rent a private car with a driver or use a ride-hailing service like Uber or Careem. The journey takes around 20-30 minutes depending on traffic. The estimated fare will be around QAR 40-60.
#
# 3. Bus: You can take the Mowasalat bus service that connects Mall of Qatar to the airport. The bus number is 109 and the journey takes around 45 minutes - 1 hour. The ticket fare is QAR 10 for adults.
#
# I hope this information is helpful.

# %%
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route(conversation):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        return response.choices[0].message.content.strip()
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Greet the user
print("Hi! How can I help you today?")

# Prompt the user to enter their question
user_message = input("You can ask your question now: ")

# Construct the conversation with the greeting message and user question
conversation = [
    {"role": "system", "content": "Hi! How can I help you today?"},
    {"role": "user", "content": user_message}
]

# Call the get_route function with the conversation
route = get_route(conversation)

print("Route Directions:")
print(route)
# Out:
# Hi! How can I help you today?
# You can ask your question now: how can i go by bus from hamad airport to pearl qatar
# Route Directions:
# You can take the Mowasalat bus service to reach The Pearl Qatar from Hamad International Airport. Follow these steps:
#
# 1. Take the Mowasalat Bus (Route 777) from Hamad International Airport.
# 2. Get down at Al Ghanim Bus Station.
# 3. From Al Ghanim Bus Station, walk to Al Diriya Metro Station (Metro Green Line).
# 4. Take the Metro Green Line towards Al Riffa Station.
# 5. Get down at Legtaifiya Station.
# 6. From the Legtaifiya Station, you can take a taxi or a shuttle bus to reach The Pearl Qatar.
#
# Note: Please check the current bus and metro schedules and timings before you start your journey.

# %%
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route(conversation):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        return response.choices[0].message.content.strip()
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

def add_system_response(conversation, response):
    conversation.append({"role": "system", "content": response})

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

while True:
    # Prompt the user to enter their message
    user_message = input("Hi! How can I help you today?")

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello
# Chatbot: Hello! How can I assist you today?
# Hi! How can I help you today?i want to know how to reach the pearl qatar from the aiport
# Chatbot: You have a few different options for getting from the airport to The Pearl-Qatar.
#
# 1. Taxi: A taxi is the most convenient option and you can easily find one at designated taxi stands at the airport. Expect to pay around 50 - 70 QAR, depending on the traffic and your final destination on The Pearl-Qatar.
#
# 2. Uber or Careem: You can also use ride-hailing services such as Uber or Careem, which have designated pick-up points at the airport. Just download the app before you arrive in Qatar.
#
# 3. Bus: You can take a bus from the airport to the nearby Lusail City and then take a Uber or Taxi to The Pearl-Qatar. There is a separate bus service from Lusail to The Pearl-Qatar but frequency is low at present.
#
# ...

# %%
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route(conversation):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        return response.choices[0].message.content.strip()
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

def add_system_response(conversation, response):
    conversation.append({"role": "system", "content": response})

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

first_message = True

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello
# Chatbot: Hello! How can I assist you today?
# hello
# Chatbot: Hello! How can I help you today?
# hello i want the route from the airport to Pearl qatar
# Chatbot: Sure, which airport are you arriving at?
# hamad
# Chatbot: To get from Hamad International Airport to The Pearl-Qatar, there are a few transportation options available:
#
# 1. Taxi: Taxis are easily available at the airport and are a convenient way to get to The Pearl-Qatar. The distance is about 25 km, and the travel time is around 30 minutes during normal traffic conditions.
#
# 2. Private transfer: A private transfer offers a more personalized and comfortable travel experience from the airport to The Pearl-Qatar. You can book a private transfer in advance or upon arrival at the airport.
#
# ...

# %%
import csv

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route_info(route_short_name, route_data):
    # Search for route information based on the route short name in the dataset
    for data in route_data:
        if data["route_short_name"] == route_short_name:
            return f"The route {data['route_short_name']} goes from {data['start_line_x']} to {data['end_line_x']}."
    return "Sorry, I couldn't find information about that route."

def get_route(conversation, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the route short name is mentioned in the response
        words = route_text.split()
        for word in words:
            if word.startswith("R"):
                route_info = get_route_info(word, route_data)
                if route_info:
                    return route_text + " " + route_info
                else:
                    return route_text + " " + "Sorry, I couldn't find information about that route."
        
        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

def add_system_response(conversation, response):
    conversation.append({"role": "system", "content": response})

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

first_message = True

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello i want to go from the airport to pearl qatar
# Chatbot: Sure, there are a few options to get from the airport to Pearl Qatar:
#
# 1. Taxi: You can take a taxi from Doha Airport to Pearl Qatar. It is a 30-minute drive and will cost you around QAR 40-50 depending on traffic.
#
# 2. Uber/Careem: You can also use ride-hailing apps like Uber or Careem to get a ride from the airport to Pearl Qatar. The fare may vary depending on the time of the day, the route, and traffic.
#
# 3. Bus: The Mowasalat bus service (Karwa) has a few routes that go to the Pearl Qatar. However, the bus system in Doha can be a bit complicated, and the frequency of buses may not be very high.
#
# 4. Private transfer: You can also arrange for a private transfer from the airport to Pearl Qatar. Several car rental companies and private taxi services offer this service. The price may vary depending on the type of vehicle and the time of the day.
#
# ...

# %%
import csv

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route_info(route_short_name, route_data):
    # Search for route information based on the route short name in the dataset
    for data in route_data:
        if data["route_short_name"] == route_short_name:
            return f"The route {route_short_name} goes from {data['start_line_x']} to {data['end_line_x']}."
    return "Sorry, I couldn't find information about that route."

def get_route(location, destination, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(location) and is_in_doha(destination):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=[
                {"role": "system", "content": f"Find the route from {location} to {destination}."},
                {"role": "user", "content": ""}
            ]
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the route short name is mentioned in the response
        words = route_text.split()
        route_short_names = set()
        for word in words:
            if word.startswith("R"):
                route_short_names.add(word)
        
        # If route identifiers are found, get corresponding short names
        if route_short_names:
            route_info = ""
            for route_short_name in route_short_names:
                info = get_route_info(route_short_name, route_data)
                if info:
                    route_info += info + " "
            if route_info:
                return route_text + " " + route_info

        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Example conversation
location = input("Please enter your location: ")
destination = input("Please enter your destination: ")

# Get the route information
route_info = get_route(location, destination, route_data)
print("Route Information:", route_info)
# Out:
# Please enter your location: airport hamad
# Please enter your destination: pearl qatar
# Route Information: There are several ways to get from Hamad International Airport to The Pearl Qatar, but one possible route is:
#
# 1. Take a taxi or private car from the airport to Al Corniche Street.
# 2. Follow Al Corniche Street north along the coast until you reach the Lusail Expressway (Al Istiqlal Road).
# 3. Turn right onto the Lusail Expressway and continue for about 7 km.
# 4. Take the exit for "The Pearl-Qatar" and follow the signs to the entrance of the island.
# 5. Once you enter The Pearl-Qatar, follow the signs to your destination.
#
# The entire journey should take about 30-45 minutes, depending on traffic conditions. It's always recommended to confirm the directions with the driver or use a GPS navigation app. Sorry, I couldn't find information about that route.

# %%
import csv

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route_info(route_short_name, route_data):
    # Search for route information based on the route short name in the dataset
    for data in route_data:
        if data["route_short_name"] == route_short_name:
            return f"The route {route_short_name} goes from {data['start_line_x']} to {data['end_line_x']}."
    return "Sorry, I couldn't find information about that route."

def get_route(location, destination, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(location) and is_in_doha(destination) and location != destination:
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=[
                {"role": "system", "content": f"Find the route from {location} to {destination}."},
                {"role": "user", "content": ""}
            ]
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the route short name is mentioned in the response
        words = route_text.split()
        route_short_names = set()
        for word in words:
            if word.startswith("R"):
                route_short_names.add(word)
        
        # If route identifiers are found, get corresponding short names
        if route_short_names:
            route_info = ""
            for route_short_name in route_short_names:
                info = get_route_info(route_short_name, route_data)
                if info:
                    route_info += info + " "
            if route_info:
                return route_text + " " + route_info

        return route_text
    else:
        return "Sorry, I couldn't generate a route. Please provide valid starting and ending points within Doha, Qatar, and make sure they are not the same."

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Start the conversation loop
print("Hi! How can I help you today?")
user_input = input("You: ")
if user_input.lower() == "exit":
    print("Goodbye!")
else:
    print("Chatbot:", "Great! Now, what's your destination from", user_input + "?")
    destination = input("You: ")
    print("Chatbot:", f"Got it! Let me find the route from {user_input} to {destination}...")
    # Get the route information
    route_info = get_route(user_input, destination, route_data)
    print("Chatbot:", route_info)
# Out:
# Hi! How can I help you today?
# You: hello
# Chatbot: Great! Now, what's your destination from hello?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 70
#      68 else:
#      69     print("Chatbot:", "Great! Now, what's your destination from", user_input + "?")
# ---> 70     destination = input("You: ")
#      71     print("Chatbot:", f"Got it! Let me find the route from {user_input} to {destination}...")
#      72     # Get the route information
#
# File ~\AppData\Local\anaconda2\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
# ...

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString
import networkx as nx
import matplotlib.pyplot as plt

# Read the stops.csv file into a DataFrame
stops_df = pd.read_csv('stops.csv')

# Convert the DataFrame to a GeoDataFrame
stops_gdf = gpd.GeoDataFrame(stops_df, geometry=gpd.points_from_xy(stops_df.stop_lon, stops_df.stop_lat))

# Read the shapes.txt file into a DataFrame
shapes_df = pd.read_csv('shapes.txt')

# Convert the DataFrame to a GeoDataFrame
shapes_gdf = gpd.GeoDataFrame(shapes_df, geometry=gpd.points_from_xy(shapes_df.shape_pt_lon, shapes_df.shape_pt_lat))

# Group the GeoDataFrame by shape_id and aggregate the points into a LineString geometry
grouped_shapes = shapes_gdf.groupby('shape_id')['geometry'].apply(lambda x: LineString(x.tolist())).reset_index()

# Convert the DataFrame to a GeoDataFrame
shape_gdf = gpd.GeoDataFrame(grouped_shapes, geometry='geometry')

# Define a function to check if the location is within Doha
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

# Define a function to get the route
def get_route(origin, destination):
    # Use your logic to determine the route from origin to destination
    # For example, you can use networkx to find the shortest path in a graph
    return "Route from {} to {} via bus line R702".format(origin, destination)

# Define a function to display the route map
def display_route_map(shape_gdf, stops_gdf, origin_stop_id, destination_stop_id):
    # Plot the shape file and the stops
    ax = shape_gdf.plot(figsize=(10, 10), color='black', linewidth=0.3)
    stops_gdf.plot(ax=ax, color='red', markersize=10)

    # Plot the edges connecting the stops along the route shape
    origin_point = stops_gdf[stops_gdf['stop_id'] == origin_stop_id]['geometry'].iloc[0]
    destination_point = stops_gdf[stops_gdf['stop_id'] == destination_stop_id]['geometry'].iloc[0]
    shortest_path = nx.shortest_path(graph, origin_stop_id, destination_stop_id)
    for i in range(len(shortest_path) - 1):
        start_point = stops_gdf[stops_gdf['stop_id'] == shortest_path[i]]['geometry'].iloc[0]
        end_point = stops_gdf[stops_gdf['stop_id'] == shortest_path[i + 1]]['geometry'].iloc[0]
        plt.plot([start_point.x, end_point.x], [start_point.y, end_point.y], color='blue', linewidth=2)
        plt.annotate(shortest_path[i], (start_point.x, start_point.y), textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate(destination_stop_id, (destination_point.x, destination_point.y), textcoords="offset points", xytext=(0,10), ha='center')

    # Show the route map
    plt.show()

# Initialize conversation with a greeting
print("Hi! How can I help you today?")

origin = None
destination = None

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    # Check if the user input is asking for route information
    if "route" in user_input.lower() or "path" in user_input.lower():
        if origin is not None and destination is not None:
            print("Chatbot: Displaying route from {} to {}...".format(origin, destination))
            display_route_map(shape_gdf, stops_gdf, origin, destination)
        else:
            print("Chatbot: Please provide the origin and destination first.")
        continue

    # Check if the user input contains location information
    if is_in_doha(user_input):
        if origin is None:
            origin = user_input
            print("Chatbot: Great! Now, what's your destination from {}? ".format(origin))
        else:
            destination = user_input
            print("Chatbot: Displaying route from {} to {}...".format(origin, destination))
            route = get_route(origin, destination)
            print("Chatbot:", route)
            display_route_map(shape_gdf, stops_gdf, origin, destination)
            origin = None
            destination = None
    else:
        print("Chatbot: Location is not within Doha, Qatar.")
# Out:
# Hi! How can I help you today?
# You: hello
# Chatbot: Great! Now, what's your destination from hello?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 64
#      61 destination = None
#      63 while True:
# ---> 64     user_input = input("You: ")
#      66     if user_input.lower() == "exit":
#      67         print("Chatbot: Goodbye!")
#
# File ~\AppData\Local\anaconda2\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# ...

# %%
import pandas as pd
from fuzzywuzzy import fuzz

# Load the routing dataset
routing_df = pd.read_csv('routing.csv')

# Define function to lookup route short names from dataset
def lookup_route_short_names(origin, destination):
    # Tokenize origin and destination
    origin_tokens = origin.split()
    destination_tokens = destination.split()
    
    # Calculate similarity and filter dataset
    similarity_threshold = 80  # Adjust as needed
    filtered_routes = routing_df[
        (routing_df['start_line_x'].apply(lambda x: any(token in x.split() for token in origin_tokens))) &
        (routing_df['end_line_x'].apply(lambda x: any(token in x.split() for token in destination_tokens))) &
        (routing_df.apply(lambda row: fuzz.token_sort_ratio(' '.join(origin_tokens), row['start_line_x']) >= similarity_threshold, axis=1)) &
        (routing_df.apply(lambda row: fuzz.token_sort_ratio(' '.join(destination_tokens), row['end_line_x']) >= similarity_threshold, axis=1))
    ]
    
    # Extract route short names from the filtered dataset
    route_short_names = filtered_routes['route_short_name'].unique()
    
    return route_short_names

# Example usage:
origin = "Lusail Bus Station"
destination = "Al Khor Aquatic Center"
route_short_names = lookup_route_short_names(origin, destination)
print("Route short names:", route_short_names)
# Out:
# C:\Users\kosman\AppData\Local\anaconda2\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Route short names: ['R702']

# %%
import pandas as pd
from fuzzywuzzy import fuzz

# Load the routing dataset
routing_df = pd.read_csv('routing.csv')

# Define function to lookup route short names from dataset
def lookup_route_short_names(origin, destination):
    # Tokenize origin and destination
    origin_tokens = origin.split()
    destination_tokens = destination.split()
    
    # Calculate similarity and filter dataset
    similarity_threshold = 80  # Adjust as needed
    filtered_routes = routing_df[
        (routing_df['start_line_x'].apply(lambda x: any(token in x.split() for token in origin_tokens))) &
        (routing_df['end_line_x'].apply(lambda x: any(token in x.split() for token in destination_tokens))) &
        (routing_df.apply(lambda row: fuzz.token_sort_ratio(' '.join(origin_tokens), row['start_line_x']) >= similarity_threshold, axis=1)) &
        (routing_df.apply(lambda row: fuzz.token_sort_ratio(' '.join(destination_tokens), row['end_line_x']) >= similarity_threshold, axis=1))
    ]
    
    # Extract route short names from the filtered dataset
    route_short_names = filtered_routes['route_short_name'].unique()
    
    return route_short_names

# Define function to process user input and get route short names
def get_route_short_names(user_input):
    # Extract origin and destination from user input (You need to implement this)
    origin = "Lusail Bus Station"  # Example origin, replace with actual extraction logic
    destination = "Al Khor Aquatic Center"  # Example destination, replace with actual extraction logic
    
    # Lookup route short names based on origin and destination
    route_short_names = lookup_route_short_names(origin, destination)
    
    return route_short_names

# Example usage:
user_input = "I want to go from Lusail to Al Khor"
route_short_names = get_route_short_names(user_input)
print("Route short names:", route_short_names)
# Out:
# Route short names: ['R702']

# %%
import csv

# Function to load route data from CSV
def load_route_data(file_path):
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

# Function to check if the location is within Doha
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

# Function to get route information based on route short name
def get_route_info(route_short_name, route_data):
    for data in route_data:
        if data["route_short_name"] == route_short_name:
            return f"The route {route_short_name} goes from {data['start_line_x']} to {data['end_line_x']}."
    return "Sorry, I couldn't find information about that route."

# Function to get route directions and additional route information
def get_route(location, destination, route_data):
    if is_in_doha(location) and is_in_doha(destination):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=[
                {"role": "system", "content": f"Find the route from {location} to {destination}."},
                {"role": "user", "content": ""}
            ]
        )
        
        # Extract route directions
        route_text = response.choices[0].message.content.strip()

        # Check for route short names in the response
        words = route_text.split()
        route_short_names = set()
        for word in words:
            if word.startswith("R"):
                route_short_names.add(word)
        
        # Get additional route information based on short names
        if route_short_names:
            route_info = ""
            for route_short_name in route_short_names:
                info = get_route_info(route_short_name, route_data)
                if info:
                    route_info += info + " "
            if route_info:
                return route_text + " " + route_info

        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Load route data from CSV
route_data = load_route_data("routing.csv")

# Example ongoing conversation
print("Hi! How can I help you today?")
while True:
    location = input("Please enter your location: ")
    destination = input("Please enter your destination: ")

    # Get the route information
    route_info = get_route(location, destination, route_data)
    print("Route Information:", route_info)

    exit_command = input("Type 'exit' to end the conversation, or press Enter to continue: ")
    if exit_command.lower() == "exit":
        break
# Out:
# Hi! How can I help you today?
# Please enter your location: lusail
# Please enter your destination: perl
# Route Information: I am sorry, but I need more context to provide accurate directions. Could you please tell me which country Lusail and Perl belong to?
# Type 'exit' to end the conversation, or press Enter to continue: qatar
# Please enter your location: lusail
# Please enter your destination: perl qatar
# Route Information: Here is one possible route from Lusail to Pearl Qatar:
#
# 1. Head south on Al Kharaij St.
# 2. Turn left onto Al Istiqlal St.
# 3. Continue onto Omar Al Mukhtar St.
# 4. Turn right onto C-Ring Rd.
# 5. Continue straight onto Al Corniche St.
# 6. Turn left onto Al Funduq St.
# 7. Continue straight onto Al Rayyan Al Jadeed St.
# 8. Turn right onto Diplomatic St.
# 9. Continue straight onto The Pearl Boulevard.
# 10. Turn left onto Costa Malaz Bay.
# 11. Turn right and continue straight onto Pearl Boulevard.
# 12. Turn left onto Periwinkle St.
# ...

# %%
import csv

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route_info(route_short_name, route_data):
    # Search for route information based on the route short name in the dataset
    for data in route_data:
        if data["route_short_name"] == route_short_name:
            return f"The route {data['route_short_name']} goes from {data['start_line_x']} to {data['end_line_x']}."
    return "Sorry, I couldn't find information about that route."

def get_route(conversation, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the route short name is mentioned in the response
        words = route_text.split()
        for word in words:
            if word.startswith("R"):
                route_info = get_route_info(word, route_data)
                if route_info:
                    return route_text + " " + route_info
                else:
                    return route_text + " " + "Sorry, I couldn't find information about that route."
        
        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

def add_system_response(conversation, response):
    conversation.append({"role": "system", "content": response})

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

first_message = True

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello
# Chatbot: Hello! How can I assist you today?
# i want to go to the airport from perl qatar
# Chatbot: I understand that you want to get to the airport from Perl Qatar. Can you please provide additional information such as which airport and what mode of transportation you prefer (taxi, bus, etc.)? This information will help me provide you with more accurate options.
# hamad airport and by bus
# Chatbot: There are several bus options available for traveling from Perl Qatar to Hamad International Airport. You can use the Mowasalat bus service which operates the public bus route number 777 from Perl Qatar to Hamad Airport. The bus runs every 20 to 30 minutes and the journey takes approximately 45 minutes to 1 hour depending on traffic conditions. The one-way fare for this service is QAR 2.
#
# ...

# %%
import csv

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_route_info(route_short_name, route_data):
    # Search for route information based on the route short name in the dataset
    for data in route_data:
        if data["route_short_name"] == route_short_name:
            return data["route_desc"]  # Change this to the column containing route names in your dataset
    return "Sorry, I couldn't find information about that route."

def get_route(conversation, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the route short name is mentioned in the response
        words = route_text.split()
        for word in words:
            if word.startswith("R"):
                route_name = get_route_info(word, route_data)
                if route_name:
                    route_text = route_text.replace(word, route_name)
                    return route_text
                else:
                    return route_text + " " + "Sorry, I couldn't find information about that route."
        
        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

first_message = True

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello
# Chatbot: Hello! How can I assist you today?
# i want to go to the airport from the perl doha
# Chatbot: Sure, I can help you with that. The best way to travel from The Pearl, Doha to the airport would be to take a taxi or use a ride-hailing service. There are several reputable taxi and ride-hailing companies operating in Doha, such as Karwa taxis, Uber, and Careem. You can download their respective apps on your smartphone and book a ride to the airport from The Pearl, Doha. The duration of the journey will depend on the traffic conditions, but it usually takes around 30-40 minutes to reach Hamad International Airport from The Pearl, Doha.
# i want bus
# ...

# %%
import csv

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = []
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data.append(row)
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_bus_route(origin, destination, route_data):
    # Search for the correct bus route based on the origin and destination
    for data in route_data:
        if data["start_line_x"] == origin and data["end_line_x"] == destination:
            return data["route_short_name"]
    return None

def get_route(conversation, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the response mentions taking a bus
        if "bus" in route_text.lower():
            # Extract origin and destination from the response
            words = route_text.split()
            origin = ""
            destination = ""
            for i, word in enumerate(words):
                if word.lower() == "from" and i < len(words) - 1:
                    origin = words[i + 1]
                elif word.lower() == "to" and i < len(words) - 1:
                    destination = words[i + 1]

            if origin and destination:
                # Get the correct bus route number from the dataset
                bus_route = get_bus_route(origin, destination, route_data)
                if bus_route:
                    route_text = route_text.replace("Bus Number 777", f"Bus Number {bus_route}")

        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

first_message = True

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello
# Chatbot: Hello! How can I assist you today?
# i want to go from lusail to aquatic center in doha
# Chatbot: Sure, you can take a taxi or use public transportation to travel from Lusail to the Aquatic Centre in Doha.
#
# If you opt for a taxi, you can easily find one on the streets of Lusail or use ride-hailing apps like Uber or Careem. The trip should take around 20-25 minutes depending on traffic conditions and would cost approximately QAR 30-40.
#
# Alternatively, you can use Doha's public transportation system, the Metro. The nearest metro station to Lusail is Lusail Marina Station which is on the Red Line. From there, take the train towards Al Wakra. Get off at the Sports City Station. From this station, you can take a short walk towards the Aquatic Centre around 10 minutes.
# bus
# ...

# %%
import csv
import re

def load_route_data(file_path):
    # Load route data from the CSV file
    route_data = {}
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data[row["route_short_name"]] = row
    return route_data

def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

def get_bus_route(origin, destination, route_data):
    # Implement your logic to get the correct bus route number based on the origin and destination
    # For demonstration purposes, let's assume a simple lookup in the route data
    for route_short_name, data in route_data.items():
        if data["start_line_x"] == origin and data["end_line_x"] == destination:
            return route_short_name
    return None

def get_route(conversation, route_data):
    # Check if both origin and destination are within Doha, Qatar
    if is_in_doha(conversation[0]["content"]) and is_in_doha(conversation[1]["content"]):
        # Use chat completion to get the route directions
        response = client.chat.completions.create(
            model="OpenAiMo",
            messages=conversation
        )
        
        # Extract and return the route directions
        route_text = response.choices[0].message.content.strip()

        # Check if the response mentions taking a bus
        if "bus" in route_text.lower():
            # Find all occurrences of "bus number (number)" in the route_text
            matches = re.findall(r'bus number (\d+)', route_text, flags=re.IGNORECASE)
            
            # Replace each match with the correct bus route number
            for match in matches:
                origin = conversation[1]["content"]  # Get origin from conversation
                destination = conversation[3]["content"]  # Get destination from conversation
                bus_route = get_bus_route(origin, destination, route_data)
                if bus_route:
                    route_text = route_text.replace(f"bus number {match}", f"bus number {bus_route}")

        return route_text
    else:
        return "Sorry, the origin or destination is not within Doha, Qatar."

# Load route data from the CSV file
route_data = load_route_data("routing.csv")

# Initialize conversation with a greeting
conversation = [{"role": "system", "content": "Hi! How can I help you today?"}]

first_message = True



while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# Hi! How can I help you today?hello
# Chatbot: Hi there! How can I assist you today?
# i want to go from lusail to aquatic center using bus
# Chatbot: Sure! To travel from Lusail to the Aquatic Center using a bus, you can follow these steps:
#
# 1. Go to the nearest bus station in Lusail.
#
# 2. Look for a bus with the route number 98.
#
# 3. Board the bus and purchase your ticket from the driver or use a smart card, if you have one.
#
# 4. The bus will stop at several locations on the way, so make sure to keep track of your destination.
#
# 5. Once you reach the Aquatic Center, get off the bus and proceed to your destination.
#
# Alternatively, you can also use the Mowasalat Karwa app to plan and track your journey. You can download it from the app store on your phone.
# exit

# %%
import csv
import re

# Load route data from CSV file into a dictionary
def load_route_data(file_path):
    route_data = {}
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data[row["route_short_name"]] = row
    return route_data

# Define function to check if the location is within Doha
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

# Function to get bus route based on origin and destination
def get_bus_route(origin, destination, route_data):
    # Implement your logic to get the correct bus route number based on origin and destination
    # This can involve searching the route_data dictionary for a matching route
    # For demonstration purposes, we'll assume a simple lookup based on origin and destination
    for route_short_name, data in route_data.items():
        if data["start_line_x"] == origin and data["end_line_x"] == destination:
            return route_short_name
    return None

# Function to replace generic bus numbers with specific route numbers
def replace_bus_numbers(route_text, route_data):
    # Find all occurrences of "bus number (number)" in the route_text
    matches = re.findall(r'bus number (\d+)', route_text, flags=re.IGNORECASE)
    
    # Replace each match with the correct bus route number from the route_data
    for match in matches:
        origin = conversation[1]["content"]  # Get origin from conversation
        destination = conversation[3]["content"]  # Get destination from conversation
        bus_route = get_bus_route(origin, destination, route_data)
        if bus_route:
            route_text = route_text.replace(f"bus number {match}", f"bus number {bus_route}")
    
    return route_text

# Load route data
route_data = load_route_data("routing.csv")

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)
# Out:
# hello
# Chatbot: Hello! How can I help you today?
# i want to go bus from lusail to aquatic center
# Chatbot: Certainly! You can take bus number 98 to get from Lusail to the Aquatic Center. Here is how you can do it:
#
# 1. Go to the nearest bus stop in Lusail. There should be a bus station nearby.
#
# 2. Wait for bus number 98. This bus goes directly to the Aquatic Center.
#
# 3. Once you see the bus coming, make sure to signal it to stop.
#
# 4. Board the bus and pay your fare either in cash or using a Karwa Smartcard.
#
# 5. Once onboard, you can relax and enjoy the ride. The bus will take you through various stops before it reaches the Aquatic Center.
#
# 6. Keep an eye out for the Aquatic Center stop and signal the driver to stop when you reach it.
#
# 7. Get off the bus and you will be right at the Aquatic Center.
#
# I hope you find this helpful!
# exit

# %%
import csv
import re

# Load route data from CSV file into a dictionary
def load_route_data(file_path):
    route_data = {}
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            route_data[row["start_line_x"], row["end_line_x"]] = row["route_short_name"]
    return route_data

# Function to check if the location is within Doha
def is_in_doha(location):
    # Implement your logic to check if the location is within Doha, Qatar
    # For simplicity, let's assume all locations are within Doha for this example
    return True

# Function to extract origin and destination from user input
def extract_origin_destination(user_input):
    # Define patterns for origin and destination extraction
    origin_pattern = r'from\s+(\w+(?:\s+\w+)*)'
    destination_pattern = r'to\s+(\w+(?:\s+\w+)*)'

    # Extract origin and destination using regular expressions
    origin = re.search(origin_pattern, user_input, flags=re.IGNORECASE)
    destination = re.search(destination_pattern, user_input, flags=re.IGNORECASE)

    # Return extracted origin and destination
    return origin.group(1), destination.group(1) if origin and destination else None, None

# Function to get bus route based on origin and destination
def get_bus_route(origin, destination, route_data):
    return route_data.get((origin, destination), "not found")

# Load route data
route_data = load_route_data("routing.csv")

while True:
    # Prompt the user to enter their message
    if first_message:
        user_message = input(conversation[0]["content"])
        first_message = False
    else:
        user_message = input()

    if user_message.lower() == "exit":
        break

    # Add user's message to the conversation
    conversation.append({"role": "user", "content": user_message})

    # Call the get_route function with the conversation
    route = get_route(conversation, route_data)

    # Add the chatbot's response to the conversation
    conversation.append({"role": "system", "content": route})

    # Display chatbot's response
    print("Chatbot:", route)

    # Extract origin and destination from user input
    origin, destination = extract_origin_destination(user_input)
        # Perform conversation logic
    if origin is not None and destination is not None:
            # Check if both origin and destination are within Doha
            if is_in_doha(origin) and is_in_doha(destination):
                # Get bus route based on origin and destination
                bus_route = get_bus_route(origin, destination, route_data)
                if bus_route != "not found":
                    # Provide response with bus route
                    print("Chatbot: You can take bus number", bus_route, "from", origin, "to", destination)
                else:
                    print("Chatbot: I'm sorry, there is no direct bus route available from", origin, "to", destination)
            else:
                print("Chatbot: I'm sorry, the origin or destination is not within Doha, Qatar.")
    else:
            print("Chatbot: Please provide both the origin and destination for your journey.")
# Out:
# i want to go from lusail to aquatic center
# Chatbot: Sure, to travel from Lusail to the Aquatic Center, you can take bus route 98 which runs directly from Lusail to the Aquatic Center.
#
# Here are the step-by-step instructions:
#
# 1. Go to the nearest bus stop in Lusail.
# 2. Check the bus schedule or download the Mowasalat Karwa app to see the timing of bus route 98.
# 3. Wait for bus route 98 to arrive.
# 4. Board the bus and buy a ticket from the driver or use a Smartcard to pay your fare.
# 5. Enjoy the ride and make sure to stay alert for your stop.
# 6. Once you arrive at the Aquatic Center, get off the bus and proceed to your destination.
#
# I hope you find this helpful! Let me know if you have any further questions.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 63
#      60 print("Chatbot:", route)
# ...
